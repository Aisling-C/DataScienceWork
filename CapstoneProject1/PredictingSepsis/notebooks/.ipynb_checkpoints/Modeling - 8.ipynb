# %% [markdown]
# # Overview

# %% [markdown]
#     -Test/Train Split
#     -Min Max Scaling
#     -Hyperparameter Estimation
#     -Model Evaluation (Precision/Recall Curves)

# %% [markdown]
# # Load Libraries & Data

# %%
import glob, os
import pandas as pd
import numpy as np
import json
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image
from scipy.stats import uniform
from datetime import datetime
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
os.chdir("../src/data")
from time_elapsed import time_elapsed

# %%
os.chdir("../../data/interim")

#Load in Data
#First, the notes
with open("Data_Notes.json", "r") as infile:  
    notes=json.load(infile)
    
os.chdir("../processed")
#Next, the actual data
df=pd.read_csv('sepsis_data_preprocessed.csv',index_col=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 231307 entries, 0 to 231306
# Data columns (total 98 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   d3_HR                 231307 non-null  float64
#  1   d3_O2Sat              231307 non-null  float64
#  2   d3_Temp               231307 non-null  float64
#  3   d3_SBP                231307 non-null  float64
#  4   d3_MAP                231307 non-null  float64
#  5   d3_DBP                231307 non-null  float64
#  6   d3_Resp               231307 non-null  float64
#  7   d3_EtCO2              231307 non-null  float64
#  8   d2_HR                 231307 non-null  float64
#  9   d2_O2Sat              231307 non-null  float64
#  10  d2_Temp               231307 non-null  float64
#  11  d2_SBP                231307 non-null  float64
#  12  d2_MAP                231307 non-null  float64
#  13  d2_DBP                231307 non-null  float64
#  14  d2_Resp               231307 non-null  float64
#  15  d2_EtCO2              231307 non-null  float64
#  16  d1_HR                 231307 non-null  float64
#  17  d1_O2Sat              231307 non-null  float64
#  18  d1_Temp               231307 non-null  float64
#  19  d1_SBP                231307 non-null  float64
#  20  d1_MAP                231307 non-null  float64
#  21  d1_DBP                231307 non-null  float64
#  22  d1_Resp               231307 non-null  float64
#  23  d1_EtCO2              231307 non-null  float64
#  24  HR                    231307 non-null  float64
#  25  O2Sat                 231307 non-null  float64
#  26  Temp                  231307 non-null  float64
#  27  SBP                   231307 non-null  float64
#  28  MAP                   231307 non-null  float64
#  29  DBP                   231307 non-null  float64
#  30  Resp                  231307 non-null  float64
#  31  EtCO2                 231307 non-null  float64
#  32  BaseExcess            231307 non-null  float64
#  33  HCO3                  231307 non-null  float64
#  34  FiO2                  231307 non-null  float64
#  35  pH                    231307 non-null  float64
#  36  PaCO2                 231307 non-null  float64
#  37  SaO2                  231307 non-null  float64
#  38  AST                   231307 non-null  float64
#  39  BUN                   231307 non-null  float64
#  40  Alkalinephos          231307 non-null  float64
#  41  Calcium               231307 non-null  float64
#  42  Chloride              231307 non-null  float64
#  43  Creatinine            231307 non-null  float64
#  44  Bilirubin_direct      231307 non-null  float64
#  45  Glucose               231307 non-null  float64
#  46  Lactate               231307 non-null  float64
#  47  Magnesium             231307 non-null  float64
#  48  Phosphate             231307 non-null  float64
#  49  Potassium             231307 non-null  float64
#  50  Bilirubin_total       231307 non-null  float64
#  51  TroponinI             231307 non-null  float64
#  52  Hct                   231307 non-null  float64
#  53  Hgb                   231307 non-null  float64
#  54  PTT                   231307 non-null  float64
#  55  WBC                   231307 non-null  float64
#  56  Fibrinogen            231307 non-null  float64
#  57  Platelets             231307 non-null  float64
#  58  Age                   231307 non-null  float64
#  59  Gender                231307 non-null  int64
#  60  Unit1                 231307 non-null  float64
#  61  Unit2                 231307 non-null  float64
#  62  HospAdmTime           231307 non-null  float64
#  63  ICULOS                231307 non-null  int64
#  64  SepsisLabel           231307 non-null  int64
#  65  id                    231307 non-null  int64
#  66  HospitalA             231307 non-null  int64
#  67  SepsisOnset           231307 non-null  int64
#  68  Pre_Sep_Sep           231307 non-null  int64
#  69  Pre_Sep_No_Sep        231307 non-null  int64
#  70  Pre_Sep_Small         231307 non-null  int64
#  71  Pre_Sepsis_Six        231307 non-null  int64
#  72  Dum_BaseExcess        231307 non-null  int64
#  73  Dum_HCO3              231307 non-null  int64
#  74  Dum_FiO2              231307 non-null  int64
#  75  Dum_pH                231307 non-null  int64
#  76  Dum_PaCO2             231307 non-null  int64
#  77  Dum_SaO2              231307 non-null  int64
#  78  Dum_AST               231307 non-null  int64
#  79  Dum_BUN               231307 non-null  int64
#  80  Dum_Alkalinephos      231307 non-null  int64
#  81  Dum_Calcium           231307 non-null  int64
#  82  Dum_Chloride          231307 non-null  int64
#  83  Dum_Creatinine        231307 non-null  int64
#  84  Dum_Bilirubin_direct  231307 non-null  int64
#  85  Dum_Glucose           231307 non-null  int64
#  86  Dum_Lactate           231307 non-null  int64
#  87  Dum_Magnesium         231307 non-null  int64
#  88  Dum_Phosphate         231307 non-null  int64
#  89  Dum_Potassium         231307 non-null  int64
#  90  Dum_Bilirubin_total   231307 non-null  int64
#  91  Dum_TroponinI         231307 non-null  int64
#  92  Dum_Hct               231307 non-null  int64
#  93  Dum_Hgb               231307 non-null  int64
#  94  Dum_PTT               231307 non-null  int64
#  95  Dum_WBC               231307 non-null  int64
#  96  Dum_Fibrinogen        231307 non-null  int64
#  97  Dum_Platelets         231307 non-null  int64
# dtypes: float64(62), int64(36)
# memory usage: 174.7 MB

# %%
#Sklearn imports
from sklearn.model_selection import train_test_split, RandomizedSearchCV, KFold, GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.dummy import DummyClassifier
from sklearn.svm import SVC
from sklearn.datasets import make_classification
from sklearn.metrics import plot_confusion_matrix, classification_report, \
roc_curve, plot_precision_recall_curve, precision_recall_curve, confusion_matrix, auc
from sklearn.feature_selection import SelectFromModel

# %% [markdown]
# ## Preventing Data Leakage in Train & Test Sets

# %%
#Generate matrix with all patient id's randomly shuffled (id_shuff)
np.random.seed(seed=105)
id_shuff=df.id.unique()
np.random.shuffle(id_shuff)
#Split into test & train arrays of 1/4 and 3/4 the original size
n=int(round(id_shuff.size*0.25,0))
test_id=id_shuff[0:n]
train_id=id_shuff[n:]

# %%
#Calculate percent of time points in test df
len(df[df.id.isin(test_id)])/(len(df))
# Out:
# 0.25011348554086127

# %%
#Calculate percent of patients with sepsis in test df 
df[df.id.isin(test_id)].SepsisOnset.sum()/459
# Out:
# 0.2549019607843137

# %%
#Create Test/Train X
X_train=df[df.id.isin(train_id)].copy()
X_test=df[df.id.isin(test_id)].copy()
#Randomize order (perhaps not needed?)
#X_train=X_train.sample(frac=1)
#X_test=X_test.sample(frac=1)

#Create Test/Train Y
y_train=pd.concat([X_train.loc[:,'Pre_Sep_Sep':'Pre_Sepsis_Six'],X_train.SepsisLabel],axis=1)
y_test=pd.concat([X_test.loc[:,'Pre_Sep_Sep':'Pre_Sepsis_Six'],X_test.SepsisLabel],axis=1)

#Drop all classifiers from X
X_train.drop(columns=['SepsisLabel','SepsisOnset', 'Pre_Sep_Sep', 'Pre_Sep_No_Sep', 'Pre_Sep_Small','Pre_Sepsis_Six','id'],inplace=True)
X_test.drop(columns=['SepsisLabel','SepsisOnset', 'Pre_Sep_Sep', 'Pre_Sep_No_Sep', 'Pre_Sep_Small','Pre_Sepsis_Six','id'],inplace=True)

# %%
#Fit Min-Max Scaler to X_train data, transform X_train and X_test data
MM_scale=MinMaxScaler()
MM_scale.fit(X_train)
X_train=MM_scale.transform(X_train)
X_test=MM_scale.transform(X_test)

#Split y_train into various classification columns 
y_train_six=y_train['Pre_Sepsis_Six']
y_train_pre_sep_small=y_train['Pre_Sep_Small']
y_train_pre_sep_2=y_train['Pre_Sep_No_Sep']
y_train_pre_sep_3=y_train['Pre_Sep_Sep']
y_train_sepsis=y_train['SepsisLabel']

#Split y_test into various classification columns 
y_test_six=y_test['Pre_Sepsis_Six']
y_test_pre_sep_small=y_test['Pre_Sep_Small']
y_test_pre_sep_2=y_test['Pre_Sep_No_Sep']
y_test_pre_sep_3=y_test['Pre_Sep_Sep']
y_test_sepsis=y_test['SepsisLabel']

#Create kfolds CV objest (to allow for sequential folding, not random - prevents data leakage in cross folds)
folds=KFold(n_splits=4)

# %% [markdown]
# # Modeling Sepsis Label

# %% [markdown]
# ## Random Forest

# %%
#Find optimal random forest parameters for modelling Sepsis Label
"""start = datetime.now()
RFC = RandomForestClassifier(random_state=42,max_features='sqrt',n_estimators=500)
max_depth = [x**2 for x in range(2,10)]
min_samples_split = [4,7,16]
min_samples_leaf = [4,7,16]
distributions = {'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}
RFC_RS=RandomizedSearchCV(RFC,distributions,random_state=42,n_iter=20,cv=folds.split(X_train),n_jobs=-1)
search_RFC_Sepsis=RFC_RS.fit(X_train, y_train_sepsis)
end = datetime.now()
time_elapsed(start,end)
search_RFC_Sepsis.best_params_"""

# %%
#best_dict=search_RFC_Sepsis.best_params_
best_dict={'min_samples_split': 7, 'min_samples_leaf': 7, 'max_depth': 4}

# %%
#Create Model
start = datetime.now()
RFC_=RandomForestClassifier(n_estimators=2000, min_samples_split=best_dict['min_samples_split'],
min_samples_leaf=best_dict['min_samples_leaf'], max_features='sqrt', max_depth=best_dict['max_depth'],
random_state=42,n_jobs=-1)
RFC_.fit(X_train,y_train_sepsis)
end = datetime.now()
time_elapsed(start,end)

# %%
#Results for Training Set
yhat = RFC_.predict_proba(X_train)
yhat = yhat[:, 1]
precision, recall, thresholds = precision_recall_curve(y_train_sepsis, yhat)
fscore = (2 * precision * recall) / (precision + recall)
ix = np.argmax(fscore)
print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
no_skill = len(y_train_sepsis[y_train_sepsis==1]) / len(y_train_sepsis)
auc_=round(auc(recall,precision),3)
plt.plot([0,1], [no_skill,no_skill], linestyle='--', label='No Skill',c='orange')
plt.scatter(recall, precision, marker='.', label='Random Forest',s=10)
plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best',s=100)
plt.text(0, .25, 'AUC: {}'.format(auc_), style='italic',
        bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})
# axis labels
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Sepsis Label Training Data')
plt.legend()
# show the plot
plt.show()

# %%
classification_

# %%
#Results for Test Set
yhat = RFC_.predict_proba(X_test)
yhat = yhat[:, 1]
precision, recall, thresholds = precision_recall_curve(y_test_sepsis, yhat)
fscore = (2 * precision * recall) / (precision + recall)
ix = np.argmax(fscore)
print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
no_skill = len(y_test_sepsis[y_test_sepsis==1]) / len(y_test_sepsis)
auc_=round(auc(recall,precision),3)
plt.plot([0,1], [no_skill,no_skill], linestyle='--', label='No Skill',c='orange')
plt.scatter(recall, precision, marker='.', label='Random Forest',s=10)
plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best',s=100)
plt.text(0, .25, 'AUC: {}'.format(auc_), style='italic',
        bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})
# axis labels
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Sepsis Label Test Data')
plt.legend()
# show the plot
plt.show()

# %%
print(classification_report(y_train_sepsis,RFC_.predict(X_train)))

# %%
RFC_.feature_importances_

# %%
r=list(X_train.columns.values)
v=list(RFC_.feature_importances_)

# %%
pd.DataFrame({'features':r,'values':v})

# %%
len(importance.index)

# %%
importance = RFC_.feature_importances_
importance = pd.DataFrame(importance, index=X_train.columns, 
                          columns=["Importance"])

importance["Std"] = np.std([tree.feature_importances_
                            for tree in RFC_.estimators_], axis=0)

x = range(importance.shape[0])
y = importance.iloc[:, 0]
yerr = importance.iloc[:, 1]
plt.subplots(figsize=(16,10))
plt.bar(x, y, yerr=yerr, align="center")
plt.xticks(ticks=range(0,91),labels=importance.index,rotation=90)
plt.show()

# %%
importance.sort

# %% [markdown]
# ## Gradient Boost

# %%
#Find optimal random forest parameters for modelling Pre Sep 2
start = datetime.now()
GB = GradientBoostingClassifier(random_state=42,max_features='sqrt',n_estimators=550)
max_depth = [3,7,12]
learning_rate=[0.001,0.01,0.1,0.25,1]
loss=['deviance', 'exponential']
distributions = {'max_depth': max_depth,'learning_rate': learning_rate,'loss': loss}
GB_RS=RandomizedSearchCV(GB,distributions,random_state=42,n_iter=20,cv=folds.split(X_train),n_jobs=-1)
search_GB_Sepsis=GB_RS.fit(X_train, y_train_pre_sep_2)
end = datetime.now()
time_elapsed(start,end)
search_GB_Sepsis.best_params_
# Out:
# This process took 01 Hours 23 Minutes 18 Seconds
# {'max_depth': 12, 'loss': 'exponential', 'learning_rate': 0.25}

# %%
best_dict=search_GB_Sepsis.best_params_

# %%
new_df=df.drop(columns=['SepsisLabel','SepsisOnset', 'Pre_Sep_Sep', 'Pre_Sep_No_Sep', 'Pre_Sep_Small','Pre_Sepsis_Six','id'],inplace=True)

# %%
GB.estimators_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-b33e14e1ec4d> in <module>
# ----> 1 GB.estimators_
#
# AttributeError: 'GradientBoostingClassifier' object has no attribute 'estimators_'

# %%
import inspect

# getmembers() returns all the 
# members of an object 
for i in inspect.getmembers(GB_):
      
    # to remove private and protected
    # functions
    if not i[0].startswith('_'):
          
        # To remove other methods that
        # doesnot start with a underscore
        if not inspect.ismethod(i[1]): 
            print(i)
# Out:
# ('alpha', 0.9)
# ('ccp_alpha', 0.0)
# ('classes_', array([0, 1], dtype=int64))
# ('criterion', 'friedman_mse')
# ('estimators_', array([[DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
# ...
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=12,
#                               max_features='sqrt',
#                               random_state=RandomState(MT19937) at 0x1CFC0965740)]],
#       dtype=object))
# ('feature_importances_', array([0.01260171, 0.00638894, 0.026161  , 0.01055052, 0.00958556,
#        0.00905589, 0.00922832, 0.00208121, 0.01208678, 0.0086685 ,
#        0.01758742, 0.00951185, 0.00839609, 0.00835004, 0.00586583,
#        0.00188032, 0.00741978, 0.00605216, 0.01982448, 0.00911336,
#        0.00672638, 0.00814204, 0.00597451, 0.00156461, 0.02676266,
#        0.01575389, 0.03898838, 0.02116267, 0.02217431, 0.02118117,
#        0.02223942, 0.00674214, 0.01352611, 0.01227765, 0.00902101,
#        0.01188718, 0.01608286, 0.00718233, 0.00801224, 0.0159614 ,
#        0.01211028, 0.01333787, 0.01343159, 0.01929589, 0.00403741,
#        0.03316832, 0.01837747, 0.0174751 , 0.01491503, 0.01677834,
#        0.00891207, 0.00748143, 0.0217378 , 0.02243546, 0.01436653,
#        0.02726783, 0.00841293, 0.0226805 , 0.02857787, 0.00312797,
#        0.00253785, 0.0018238 , 0.02720619, 0.09713383, 0.0017278 ,
#        0.00270823, 0.00137693, 0.00229684, 0.00219949, 0.00152858,
#        0.00230853, 0.00220223, 0.00096473, 0.00115049, 0.00226916,
#        0.00119062, 0.00104965, 0.00179689, 0.0022018 , 0.00337918,
#        0.00282599, 0.00350975, 0.00226796, 0.0017187 , 0.00216165,
#        0.00320516, 0.00064723, 0.00172622, 0.00086184, 0.00160783,
#        0.00071444]))
# ('init', None)
# ('init_', DummyClassifier(strategy='prior'))
# ('learning_rate', 0.25)
# ('loss', 'exponential')
# ('loss_', <sklearn.ensemble._gb_losses.ExponentialLoss object at 0x000001CFBB053430>)
# ('max_depth', 12)
# ('max_features', 'sqrt')
# ('max_features_', 9)
# ('max_leaf_nodes', None)
# ('min_impurity_decrease', 0.0)
# ('min_impurity_split', None)
# ('min_samples_leaf', 1)
# ('min_samples_split', 2)
# ('min_weight_fraction_leaf', 0.0)
# ('n_classes_', 2)
# ('n_estimators', 550)
# ('n_estimators_', 550)
# ('n_features_', 91)
# ('n_features_in_', 91)
# ('n_iter_no_change', None)
# ('presort', 'deprecated')
# ('random_state', 42)
# ('subsample', 1.0)
# ('tol', 0.0001)
# ('train_score_', array([2.09701030e-01, 1.88039321e-01, 1.68564977e-01, 1.55725292e-01,
#        1.44469024e-01, 1.35178353e-01, 1.26192390e-01, 1.15966626e-01,
#        1.07410683e-01, 9.94593284e-02, 9.28882863e-02, 8.73897409e-02,
#        8.01306836e-02, 7.56075524e-02, 6.98000209e-02, 6.49215895e-02,
#        6.24141206e-02, 5.82929989e-02, 5.41149084e-02, 5.07107476e-02,
#        4.73927723e-02, 4.42141143e-02, 4.16747123e-02, 4.01984552e-02,
#        3.80175986e-02, 3.55466934e-02, 3.30458497e-02, 3.13397065e-02,
#        2.98236499e-02, 2.82423566e-02, 2.73607300e-02, 2.61606527e-02,
#        2.45391700e-02, 2.25788993e-02, 2.11192238e-02, 1.96885417e-02,
#        1.83816668e-02, 1.71284835e-02, 1.57815972e-02, 1.46523936e-02,
#        1.36597317e-02, 1.30391673e-02, 1.23662816e-02, 1.18579998e-02,
#        1.12351823e-02, 1.05586399e-02, 9.64579625e-03, 9.26866706e-03,
#        8.92759370e-03, 8.68346501e-03, 8.36716793e-03, 8.04327067e-03,
#        7.53761309e-03, 7.11660063e-03, 6.81827930e-03, 6.50968843e-03,
#        6.18769678e-03, 5.81242698e-03, 5.55089759e-03, 5.30064703e-03,
#        9.09096852e-12, 8.78703698e-12, 8.46816819e-12, 8.04977553e-12,
#        7.41459140e-12, 7.08778876e-12, 6.86720273e-12, 6.61400093e-12,
#        6.37236993e-12, 6.15345296e-12, 5.96517077e-12, 5.44410752e-12,
#        5.25441644e-12, 5.05982088e-12, 4.83061913e-12, 4.50723471e-12,
#        4.31038380e-12, 4.10250683e-12, 3.85128317e-12, 3.75444553e-12,
#        3.54119325e-12, 3.37930926e-12, 3.17996117e-12, 3.10878086e-12,
#        3.01826992e-12, 2.90453775e-12, 2.79337535e-12, 2.68460323e-12,
#        2.61289425e-12, 2.52921525e-12, 2.44303711e-12, 2.34606222e-12,
#        2.21279185e-12, 2.07504810e-12, 1.94029739e-12, 1.82420865e-12,
#        1.74894828e-12, 1.67387140e-12, 1.59344306e-12, 1.54932675e-12,
#        1.45588651e-12, 1.40526629e-12, 1.31818815e-12, 1.23349602e-12,
#        1.12644146e-12, 1.08165436e-12]))
# ('validation_fraction', 0.1)
# ('verbose', 0)
# ('warm_start', False)

# %%
importance = GB_.feature_importances_
importance = pd.DataFrame(importance, index=df.columns, 
                          columns=["Importance"])

x = range(importance.shape[0])
y = importance.iloc[:, 0]
plt.subplots(figsize=(16,10))
plt.bar(x, y, align="center")
plt.xticks(ticks=range(0,91),labels=importance.index,rotation=90)
plt.show()

# %%
search_GB_Sepsis.cv_results_
# Out:
# {'mean_fit_time': array([265.05740029, 270.11113185, 842.45057654, 833.67880088,
#         832.46111578, 174.72671068, 383.34798378, 173.62538809,
#         178.47996199, 181.55077195, 399.37340993, 406.01488119,
#         882.2466054 , 425.84555566, 862.31486344, 390.01973432,
#         373.18780738, 804.53531241, 369.33843064, 161.40980685]),
#  'std_fit_time': array([ 0.65283385,  0.68734349, 13.26520554, 16.42851286, 13.97900384,
#          2.00553098,  4.97918439,  3.23462227,  2.01111032,  1.11735222,
#          4.37978463,  6.2276743 ,  8.88857241,  9.8241215 ,  7.04416515,
#          2.85458918,  5.25607859, 12.94827713,  5.83582956, 10.15911157]),
#  'mean_score_time': array([1.95185626, 1.6649313 , 2.79191118, 2.79871005, 3.29621381,
#         1.6815449 , 2.16931677, 1.72759151, 1.97564685, 1.90141892,
#         2.47983652, 2.1309917 , 2.63456875, 2.08804005, 2.8772828 ,
#         2.19387949, 2.18592709, 2.1099841 , 2.19481832, 0.99361962]),
#  'std_score_time': array([0.02846709, 0.02662392, 0.07513703, 0.10304319, 0.18115095,
#         0.01707172, 0.03370599, 0.02205926, 0.04100806, 0.04827478,
#         0.11331966, 0.02472666, 0.11980984, 0.10059334, 0.01896733,
#         0.06371233, 0.02208392, 0.81067892, 0.10057878, 0.44280835]),
#  'param_max_depth': masked_array(data=[3, 3, 12, 12, 12, 3, 7, 3, 3, 3, 7, 7, 12, 7, 12, 7, 7,
#                     12, 7, 3],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_loss': masked_array(data=['exponential', 'exponential', 'exponential',
#                     'exponential', 'deviance', 'exponential',
#                     'exponential', 'deviance', 'deviance', 'deviance',
#                     'exponential', 'exponential', 'exponential',
#                     'deviance', 'exponential', 'exponential', 'deviance',
#                     'deviance', 'deviance', 'exponential'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_learning_rate': masked_array(data=[1, 0.1, 0.25, 0.1, 0.01, 0.01, 1, 1, 0.1, 0.001, 0.001,
#                     0.1, 0.001, 0.1, 0.01, 0.25, 0.001, 0.001, 1, 0.001],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_depth': 3, 'loss': 'exponential', 'learning_rate': 1},
#   {'max_depth': 3, 'loss': 'exponential', 'learning_rate': 0.1},
#   {'max_depth': 12, 'loss': 'exponential', 'learning_rate': 0.25},
#   {'max_depth': 12, 'loss': 'exponential', 'learning_rate': 0.1},
#   {'max_depth': 12, 'loss': 'deviance', 'learning_rate': 0.01},
#   {'max_depth': 3, 'loss': 'exponential', 'learning_rate': 0.01},
#   {'max_depth': 7, 'loss': 'exponential', 'learning_rate': 1},
#   {'max_depth': 3, 'loss': 'deviance', 'learning_rate': 1},
#   {'max_depth': 3, 'loss': 'deviance', 'learning_rate': 0.1},
#   {'max_depth': 3, 'loss': 'deviance', 'learning_rate': 0.001},
#   {'max_depth': 7, 'loss': 'exponential', 'learning_rate': 0.001},
#   {'max_depth': 7, 'loss': 'exponential', 'learning_rate': 0.1},
#   {'max_depth': 12, 'loss': 'exponential', 'learning_rate': 0.001},
#   {'max_depth': 7, 'loss': 'deviance', 'learning_rate': 0.1},
#   {'max_depth': 12, 'loss': 'exponential', 'learning_rate': 0.01},
#   {'max_depth': 7, 'loss': 'exponential', 'learning_rate': 0.25},
#   {'max_depth': 7, 'loss': 'deviance', 'learning_rate': 0.001},
#   {'max_depth': 12, 'loss': 'deviance', 'learning_rate': 0.001},
#   {'max_depth': 7, 'loss': 'deviance', 'learning_rate': 1},
#   {'max_depth': 3, 'loss': 'exponential', 'learning_rate': 0.001}],
#  'split0_test_score': array([0.97818467, 0.98042155, 0.98254312, 0.98254312, 0.98254312,
#         0.98254312, 0.98224334, 0.97045937, 0.97527903, 0.98254312,
#         0.98254312, 0.98254312, 0.98254312, 0.98055991, 0.98254312,
#         0.98252006, 0.98254312, 0.98254312, 0.90755004, 0.98254312]),
#  'split1_test_score': array([0.98215109, 0.98388064, 0.98411124, 0.98411124, 0.98411124,
#         0.98411124, 0.98408818, 0.4412877 , 0.98254312, 0.98411124,
#         0.98411124, 0.98411124, 0.98411124, 0.98286597, 0.98411124,
#         0.98420349, 0.98411124, 0.98411124, 0.27529748, 0.98411124]),
#  'split2_test_score': array([0.98526393, 0.98745474, 0.98821576, 0.98821576, 0.98821576,
#         0.98821576, 0.98816964, 0.03823536, 0.98745474, 0.98821576,
#         0.98821576, 0.98821576, 0.98821576, 0.98713189, 0.98821576,
#         0.98800821, 0.98821576, 0.98821576, 0.70698522, 0.98821576]),
#  'split3_test_score': array([0.98853862, 0.98966861, 0.98966861, 0.98966861, 0.98966861,
#         0.98966861, 0.98966861, 0.68692203, 0.98918433, 0.98966861,
#         0.98966861, 0.98966861, 0.98966861, 0.98867698, 0.98966861,
#         0.98966861, 0.98966861, 0.98966861, 0.8590734 , 0.98966861]),
#  'mean_test_score': array([0.98353458, 0.98535639, 0.98613468, 0.98613468, 0.98613468,
#         0.98613468, 0.98604244, 0.53422612, 0.98361531, 0.98613468,
#         0.98613468, 0.98613468, 0.98613468, 0.98480869, 0.98613468,
#         0.98610009, 0.98613468, 0.98613468, 0.68722654, 0.98613468]),
#  'std_test_score': array([0.00382644, 0.00351884, 0.00290745, 0.00290745, 0.00290745,
#         0.00290745, 0.00299693, 0.34214758, 0.0053944 , 0.00290745,
#         0.00290745, 0.00290745, 0.00290745, 0.00324758, 0.00290745,
#         0.00286308, 0.00290745, 0.00290745, 0.24907315, 0.00290745]),
#  'rank_test_score': array([18, 15,  1,  1,  1,  1, 14, 20, 17,  1,  1,  1,  1, 16,  1, 13,  1,
#          1, 19,  1])}

# %%
best_dict={'max_depth': 4, 'loss': 'exponential', 'learning_rate': 0.25}

# %%
#Create Model
start = datetime.now()
GB_=GradientBoostingClassifier(n_estimators=250, learning_rate=best_dict['learning_rate'],
loss=best_dict['loss'], max_features='sqrt', max_depth=best_dict['max_depth'], random_state=42)
GB_.fit(X_train,y_train_pre_sep_2)
end = datetime.now()
time_elapsed(start,end)
# Out:
# This process took 00 Hours 00 Minutes 35 Seconds

# %%
#Results for Training Set
yhat = GB_.predict_proba(X_train)
yhat = yhat[:, 1]
precision, recall, thresholds = precision_recall_curve(y_train_pre_sep_2, yhat)
fscore = (2 * precision * recall) / (precision + recall)
ix = np.argmax(fscore)
print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
no_skill = len(y_train_sepsis[y_train_sepsis==1]) / len(y_train_sepsis)
auc_=round(auc(recall,precision),3)
plt.plot([0,1], [no_skill,no_skill], linestyle='--', label='No Skill',c='orange')
plt.scatter(recall, precision, marker='.', label='Random Forest',s=10)
plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best',s=100)
plt.text(0, .25, 'AUC: {}'.format(auc_), style='italic',
        bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})
# axis labels
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Sepsis Label Training Data')
plt.legend()
# show the plot
plt.show()
# Out:
# Best Threshold=0.103315, F-Score=0.633

# %%
print(classification_report(y_train_pre_sep_2,GB_.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    171049
#            1       0.94      0.13      0.23      2405
#
#     accuracy                           0.99    173454
#    macro avg       0.97      0.57      0.61    173454
# weighted avg       0.99      0.99      0.98    173454

# %%
y_train_pre_sep_2.value_counts()
# Out:
# 0    171049
# 1      2405
# Name: Pre_Sep_No_Sep, dtype: int64

# %%
y_test_pre_sep_2.value_counts()
# Out:
# 0    57026
# 1      827
# Name: Pre_Sep_No_Sep, dtype: int64

# %%
1/60
# Out:
# 0.016666666666666666

# %%
confusion_matrix(y_train_pre_sep_2,GB_.predict(X_train))
# Out:
# array([[171047,      2],
#        [    26,   2379]], dtype=int64)

# %%
#Results for Test Set
yhat = GB_.predict_proba(X_test)
yhat = yhat[:, 1]
precision, recall, thresholds = precision_recall_curve(y_test_pre_sep_2, yhat)
fscore = (2 * precision * recall) / (precision + recall)
ix = np.argmax(fscore)
print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
no_skill = len(y_test_sepsis[y_test_sepsis==1]) / len(y_test_sepsis)
auc_=round(auc(recall,precision),3)
plt.plot([0,1], [no_skill,no_skill], linestyle='--', label='No Skill',c='orange')
plt.scatter(recall, precision, marker='.', label='Random Forest',s=10)
plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best',s=100)
plt.text(0, .25, 'AUC: {}'.format(auc_), style='italic',
        bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})
# axis labels
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Sepsis Label Test Data')
plt.legend()
# show the plot
plt.show()
# Out:
# <ipython-input-55-db9bef7f5ae0>:5: RuntimeWarning: invalid value encountered in true_divide
#   fscore = (2 * precision * recall) / (precision + recall)
# Best Threshold=0.864201, F-Score=nan

# %%
print(classification_report(y_test_pre_sep_2,GB_.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     57026
#            1       0.05      0.01      0.01       827
#
#     accuracy                           0.98     57853
#    macro avg       0.52      0.50      0.50     57853
# weighted avg       0.97      0.98      0.98     57853

# %%
#Find optimal random forest parameters for modelling Sepsis Label
"""start = datetime.now()
RFC = RandomForestClassifier(random_state=42,max_features='sqrt',n_estimators=500)
max_depth = [x**2 for x in range(2,10)]
min_samples_split = [4,7,16]
min_samples_leaf = [4,7,16]
distributions = {'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}
RFC_RS=RandomizedSearchCV(RFC,distributions,random_state=42,n_iter=20,cv=folds.split(X_train),n_jobs=-1)
search_RFC_Sepsis=RFC_RS.fit(X_train, y_train_sepsis)
end = datetime.now()
time_elapsed(start,end)
search_RFC_Sepsis.best_params_"""

# %%
#best_dict=search_RFC_Sepsis.best_params_
best_dict={'min_samples_split': 7, 'min_samples_leaf': 7, 'max_depth': 4}

# %%
#Create Model
start = datetime.now()
RFC_=RandomForestClassifier(n_estimators=2000, min_samples_split=best_dict['min_samples_split'],
min_samples_leaf=best_dict['min_samples_leaf'], max_features='sqrt', max_depth=best_dict['max_depth'],
random_state=42,n_jobs=-1)
RFC_.fit(X_train,y_train_pre_sep_3)
end = datetime.now()
time_elapsed(start,end)
# Out:
# This process took 00 Hours 00 Minutes 57 Seconds

# %%
#Results for Training Set
yhat = RFC_.predict_proba(X_train)
yhat = yhat[:, 1]
precision, recall, thresholds = precision_recall_curve(y_train_pre_sep_2, yhat)
fscore = (2 * precision * recall) / (precision + recall)
ix = np.argmax(fscore)
print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
no_skill = len(y_train_sepsis[y_train_sepsis==1]) / len(y_train_sepsis)
auc_=round(auc(recall,precision),3)
plt.plot([0,1], [no_skill,no_skill], linestyle='--', label='No Skill',c='orange')
plt.scatter(recall, precision, marker='.', label='Random Forest',s=10)
plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best',s=100)
plt.text(0, .25, 'AUC: {}'.format(auc_), style='italic',
        bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})
# axis labels
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Sepsis Label Training Data')
plt.legend()
# show the plot
plt.show()
# Out:
# Best Threshold=0.054618, F-Score=0.245

# %%
print(classification_report(y_train_pre_sep_3,RFC_.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98    167787
#            1       0.00      0.00      0.00      2405
#            2       0.00      0.00      0.00      3262
#
#     accuracy                           0.97    173454
#    macro avg       0.32      0.33      0.33    173454
# weighted avg       0.94      0.97      0.95    173454
# C:\Users\amcas\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Results for Test Set
yhat = RFC_.predict_proba(X_test)
yhat = yhat[:, 1]
precision, recall, thresholds = precision_recall_curve(y_test_pre_sep_3, yhat)
fscore = (2 * precision * recall) / (precision + recall)
ix = np.argmax(fscore)
print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
no_skill = len(y_test_sepsis[y_test_sepsis==1]) / len(y_test_sepsis)
auc_=round(auc(recall,precision),3)
plt.plot([0,1], [no_skill,no_skill], linestyle='--', label='No Skill',c='orange')
plt.scatter(recall, precision, marker='.', label='Random Forest',s=10)
plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best',s=100)
plt.text(0, .25, 'AUC: {}'.format(auc_), style='italic',
        bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})
# axis labels
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Sepsis Label Test Data')
plt.legend()
# show the plot
plt.show()

# %%
RFC_.feature_importances_

# %%
r=list(X_train.columns.values)
v=list(RFC_.feature_importances_)

# %%
pd.DataFrame({'features':r,'values':v})

# %%
len(importance.index)

# %%
importance = RFC_.feature_importances_
importance = pd.DataFrame(importance, index=X_train.columns, 
                          columns=["Importance"])

importance["Std"] = np.std([tree.feature_importances_
                            for tree in RFC_.estimators_], axis=0)

x = range(importance.shape[0])
y = importance.iloc[:, 0]
yerr = importance.iloc[:, 1]
plt.subplots(figsize=(16,10))
plt.bar(x, y, yerr=yerr, align="center")
plt.xticks(ticks=range(0,91),labels=importance.index,rotation=90)
plt.show()

# %%
importance.sort
