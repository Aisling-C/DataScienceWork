# %% [markdown]
# # Overview
#
# The purpose of this notebook is to combine data from different sources and clean it. Two data sets are saved at the end:
# * **Dataset 1:** Population & diabetes for all counties, 2004 to 2017. This data will only be used for exploring nationwide trends.
# * **Dataset 2:** Diabetes and census demographic (ACS) data for counties with popultation >65,000, 2006 to 2017. This data set will be used for the predictive model.
#
#
#
# **Notes**
# * All data from Puerto Rico has been removed from both data sets due to a lack of explanatory data (education level & age ratio).
# * Counties missing four or more years worth of ACS data (due to changing population numbers, either over or under the 65,000 population limit) are removed from dataset 2.
# * In any counties missing three or less years worth of data, the data is interpolated or backfilled if no points exist preceeding that year.
# * Much of the counties have null values for the pacific islander race for all years; if so, the null values are replaced with 0.

# %% [markdown]
# # Code Navigation
# * [1. Load Packages & Data](#1.LoadPackages&Data)
# * [2. All Counties](#2.AllCounties)
#     * [2.1. Prep: Population Data](#2.1.Prep:PopulationData)
#     * [2.2. Prep: Age Ratio Data](#2.2.Prep:AgeRatioData)
#     * [2.3. Prep: Diabetes Data](#2.3.Prep:DiabetesData)
#     * [2.4. Combine: All County Data](#2.4.Combine:AllCountyData)
# * [3. Populous Counties + ACS](#3.PopulousCounties+ACS)
#     * [3.1. Prep: ACS Demographic Data](#3.1.Prep:ACSDemographicData)
#     * [3.2. Combine Demographic & Diabetes Data](#3.2.Combine:Demographic&DiabetesData)
# * [4. Saving Data](#4.SavingData)

# %% [markdown]
# ## 1. Load Packages & Data <a class="anchor" id="1.LoadPackages&Data"></a>

# %%
import requests
import pandas as pd
import csv
import os
import sys
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
from tqdm import tqdm

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

#Change directory to project root directory
os.chdir("..")

#Import custom code
from src.code_flow.CreateJupyterNotebookHeadings import jupyternotebookheadings1, jupyternotebookheadings2

# %%
#Read in csv from raw data folder
df_diabetes=pd.read_csv('data/raw/diabetes_data_2004_2017.csv',index_col=0)
df_census=pd.read_csv('data/raw/ACS_data_2006_2019.csv',index_col=0)
df_pop=pd.read_csv('data/raw/population_est_2000_2019.csv',index_col=0)
df_pop_age=pd.read_csv('data/raw/population_age_ratio_2010.csv',index_col=0)

# %% [markdown]
# ## 2. All Counties <a class="anchor" id="2.AllCounties"></a>

# %% [markdown]
# ### 2.1. Prep: Population Data <a class="anchor" id="2.1.Prep:PopulationData"></a>

# %%
#Obtain year from date data, convert to an integer
df_pop.year=pd.to_datetime(df_pop.year).dt.year.astype('int64')

#Convert the value column to type float
df_pop.value=df_pop.value.astype('float64')

#List any duplicates - head & tail
df_pop[df_pop.duplicated(subset=['county','state','year'])].head(5)
# Out:
#                county   state     value  state_fips  county_fips  year  \
# 1    Aroostook County   Maine   73872.0          23            3  2000
# 13  Cumberland County   Maine  266109.0          23            5  2000
# 25    Franklin County   Maine   29498.0          23            7  2000
# 37     Hancock County   Maine   51967.0          23            9  2000
# 49    Kennebec County   Maine  117177.0          23           11  2000
#
#       variable
# 1   population
# 13  population
# 25  population
# 37  population
# 49  population

# %%
df_pop[df_pop.duplicated(subset=['county','state','year'])].tail(5)
# Out:
#                   county         state    value  state_fips  county_fips  \
# 38617  Yabucoa Municipio   Puerto Rico  37941.0          72          151
# 38618  Yabucoa Municipio   Puerto Rico  37874.0          72          151
# 38628    Yauco Municipio   Puerto Rico  42043.0          72          153
# 38629    Yauco Municipio   Puerto Rico  41947.0          72          153
# 38630    Yauco Municipio   Puerto Rico  41828.0          72          153
#
#        year    variable
# 38617  2010  population
# 38618  2010  population
# 38628  2010  population
# 38629  2010  population
# 38630  2010  population

# %%
#These are duplicate entries from 2000 & 2010 from the census data, drop them
df_pop.drop_duplicates(subset=['county','state','year'],keep='first',inplace=True)

#Remove population data between 2000-2003, 2018 & 2019 
#Since there's no other data to match from the CDC
df_pop=df_pop[~(df_pop.year.isin([2000,2001,2002,2003,2018,2019]))]

#Remove preceeding white spaces from state names
df_pop.state=df_pop.state.str.strip()

# %%
#Shannon County SD was renamed Oglala Lakota county in 2013 - will fix in all the data sets

#Rename any Shannon County entries as Oglala Lakota County & rename county fips
cond_s=df_pop.county=='Shannon County'
cond_o=df_pop.county=='Oglala Lakota County'
cond_sd=df_pop.state=='South Dakota'
df_pop.loc[(cond_s)&(cond_sd),'county_fips']=102
df_pop.loc[(cond_s)&(cond_sd),'county']='Oglala Lakota County'
#Pop one of the duplicate values
ind=df_pop[(cond_o) & (df_pop.year==2010)].index[0]
df_pop=df_pop.drop(ind).reset_index(drop=True)
#Ensure there's only one entry for 2010
cond_o=df_pop.county=='Oglala Lakota County'
df_pop[(cond_o) & (df_pop.year==2010)]
# Out:
#                     county         state    value  state_fips  county_fips  \
# 8910  Oglala Lakota County  South Dakota  13586.0          46          102
#
#       year    variable
# 8910  2010  population

# %% [markdown]
# ### 2.2. Prep: Age Ratio Data <a class="anchor" id="2.2.Prep:AgeRatioData"></a>

# %%
#Rename columns
col_name={'STATE':'state_fips','COUNTY':'county_fips','STNAME':'state','CTYNAME':'county'}
df_pop_age.rename(columns=col_name,inplace=True)

# %%
#Rename Shannon County entry as Oglala Lakota County, change county fips
cond_s=df_pop_age.county=='Shannon County'
cond_sd=df_pop_age.state=='South Dakota'
df_pop_age.loc[(cond_s)&(cond_sd),'county_fips']=102
df_pop_age.loc[(cond_s)&(cond_sd),'county']='Oglala Lakota County'

# %%
#Merge with all population data
id_=['state_fips','county_fips']
df_pop=df_pop.merge(df_pop_age.drop(columns=['state','county']),right_on=id_,left_on=id_,how='left')

# %%
df_pop_age.head()
# Out:
#    state_fips  county_fips    state          county  adult_pop_ratio
# 0           1            1  Alabama  Autauga County         0.704971
# 1           1            3  Alabama  Baldwin County         0.746860
# 2           1            5  Alabama  Barbour County         0.757141
# 3           1            7  Alabama     Bibb County         0.749114
# 4           1            9  Alabama   Blount County         0.728592

# %%
df_pop.head()
# Out:
#              county  state    value  state_fips  county_fips  year  \
# 0  Aroostook County  Maine  72959.0          23            3  2004
# 1  Aroostook County  Maine  72881.0          23            3  2005
# 2  Aroostook County  Maine  72827.0          23            3  2006
# 3  Aroostook County  Maine  72711.0          23            3  2007
# 4  Aroostook County  Maine  72542.0          23            3  2008
#
#      variable  adult_pop_ratio
# 0  population         0.774986
# 1  population         0.774986
# 2  population         0.774986
# 3  population         0.774986
# 4  population         0.774986

# %%
#Calculate the adult population & drop the ratio column
df_pop['adult_pop']=round(df_pop.value*df_pop.adult_pop_ratio,0)
df_pop.drop(columns=['adult_pop_ratio'],inplace=True)

#Rename the value column, print a sample of the dataframe
df_pop.rename(columns={'value':'total_population'},inplace=True)
df_pop.sort_values(['state','county','year']).head(5)
# Out:
#                county    state  total_population  state_fips  county_fips  \
# 13107  Autauga County  Alabama           48366.0           1            1
# 13108  Autauga County  Alabama           49676.0           1            1
# 13109  Autauga County  Alabama           51328.0           1            1
# 13110  Autauga County  Alabama           52405.0           1            1
# 13111  Autauga County  Alabama           53277.0           1            1
#
#        year    variable  adult_pop
# 13107  2004  population    34097.0
# 13108  2005  population    35020.0
# 13109  2006  population    36185.0
# 13110  2007  population    36944.0
# 13111  2008  population    37559.0

# %% [markdown]
# ### 2.3. Prep: Diabetes Data <a class="anchor" id="2.3.Prep:DiabetesData"></a>

# %%
#Recast CountyFIPS as a string
df_diabetes.CountyFIPS=df_diabetes.CountyFIPS.astype(str)

#Create a county_fips column that is just the county fips number, not the state to match the census data
df_diabetes['county_fips']=df_diabetes.CountyFIPS.apply(lambda x: x[-3:])
def fips_state(x):
    """This function takes the combo state/county fips string and returns the state fips number"""
    if len(x)==5:
        return x[:2]
    else:
        return x[0]
    
#Do the same for state fips
df_diabetes['state_fips']=df_diabetes.CountyFIPS.apply(fips_state)
df_diabetes.drop(columns='CountyFIPS',inplace=True)

#Recast fips columns as integers
df_diabetes.county_fips=df_diabetes.county_fips.astype('int64')
df_diabetes.state_fips=df_diabetes.state_fips.astype('int64')

#Rename the columns to match the census data style
df_diabetes.rename(columns={'County':'county','State':'state','Percentage':'diabetes_%','Year':'year',
                           ' Upper Limit':'diabetes_%_upper','Lower Limit':'diabetes_%_lower'},inplace=True)
#Melt the dataframe
df_diabetes=pd.melt(df_diabetes,id_vars=['county','state','year','county_fips','state_fips'],
                    value_name='value',var_name='variable')

#Convert the value from string to numeric type
df_diabetes.value=pd.to_numeric(df_diabetes.value,errors='coerce')

#Reorder diabetes df columns to match others
df_diabetes=df_diabetes[['county','state','value','state_fips','county_fips','year','variable']]

#Make all county names completely lowercase
df_diabetes.county=df_diabetes.county.str.lower()

#Print a sample of the dataframe
df_diabetes.head()
# Out:
#            county    state  value  state_fips  county_fips  year    variable
# 0  autauga county  Alabama   10.1           1            1  2004  diabetes_%
# 1  autauga county  Alabama   11.5           1            1  2005  diabetes_%
# 2  autauga county  Alabama   11.0           1            1  2006  diabetes_%
# 3  autauga county  Alabama   11.2           1            1  2007  diabetes_%
# 4  autauga county  Alabama   10.9           1            1  2008  diabetes_%

# %% [markdown]
# ### 2.4. Combine: All County Data <a class="anchor" id="2.4.CombiningAllCountyData"></a>

# %%
#Obtain just diabetes prevelance data and name value column after it
df_diabetes_=df_diabetes[df_diabetes.variable=='diabetes_%'].drop(columns='variable').rename(columns={'value':'diabetes_%'})
#Resolve Oglala Lakota County issues
cond_s=df_diabetes_.county=='shannon county'
cond_o=df_diabetes_.county=='oglala lakota county'
cond_sd=df_diabetes_.state=='South Dakota'
df_diabetes_.loc[(cond_s)&(cond_sd),'county_fips']=102
df_diabetes_.loc[(cond_s)&(cond_sd),'county']='oglala lakota county'
#Drop any rows that contain empty values for Oglala Lakota County
index_val=df_diabetes_[(cond_o) & (cond_sd)][df_diabetes_[(cond_o) & (cond_sd)]['diabetes_%'].isna()].index.values
df_diabetes_=df_diabetes_.drop(index_val).reset_index(drop=True)
#Doublecheck
cond_o=df_diabetes_.county=='oglala lakota county'
cond_sd=df_diabetes_.state=='South Dakota'
index_val=df_diabetes_[(cond_o) & (cond_sd)][df_diabetes_[(cond_o) & (cond_sd)]['diabetes_%'].isna()].index.values
df_diabetes_=df_diabetes_.drop(index_val).reset_index(drop=True)

# %%
#Merge diabetes & all county population data 
id_=['state_fips','county_fips','year']
df_pop_diabetes=df_diabetes_.merge(df_pop.drop(columns=['state','county']),right_on=id_,left_on=id_,how='right')

#Inspect df for missing diabetes values
df_pop_diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45089 entries, 0 to 45088
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   county            45089 non-null  object
#  1   state             45089 non-null  object
#  2   diabetes_%        45060 non-null  float64
#  3   state_fips        45089 non-null  int64
#  4   county_fips       45089 non-null  int64
#  5   year              45089 non-null  int64
#  6   total_population  45089 non-null  float64
#  7   variable          45089 non-null  object
#  8   adult_pop         43989 non-null  float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 3.4+ MB

# %%
#Make a list of counties missing diabetes prevelance data
missing_counties=list(df_diabetes_[df_diabetes_['diabetes_%'].isna()].county.unique())
missing_counties
# Out:
# ['hoonah-angoon census area',
#  'kusilvak census area',
#  'petersburg census area',
#  'prince of wales - outer ketchikan',
#  'prince of wales-hyder censu',
#  'skagway municipality',
#  'skagway-hoonah-angoon',
#  'wade hampton census area',
#  'wrangell city and borough',
#  'wrangell-petersburg census area',
#  'bedford city']

# %%
#Remove them from dataframe
df_pop_diabetes=df_pop_diabetes[~df_pop_diabetes.county.isin(missing_counties)]

#Verify there are no missing diabetes values
df_pop_diabetes[df_pop_diabetes['diabetes_%'].isna()]
# Out:
# Empty DataFrame
# Columns: [county, state, diabetes_%, state_fips, county_fips, year, total_population, variable, adult_pop]
# Index: []

# %%
#Drop Puerto Rico from this data set - don't have age ratio
df_pop_diabetes=df_pop_diabetes[~(df_pop_diabetes.state_fips==72)]

#Ensure there are no missing values
df_pop_diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43904 entries, 0 to 44542
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   county            43904 non-null  object
#  1   state             43904 non-null  object
#  2   diabetes_%        43904 non-null  float64
#  3   state_fips        43904 non-null  int64
#  4   county_fips       43904 non-null  int64
#  5   year              43904 non-null  int64
#  6   total_population  43904 non-null  float64
#  7   variable          43904 non-null  object
#  8   adult_pop         43904 non-null  float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 3.3+ MB

# %%
#Calculate number of adults with diabetes per county per year
df_pop_diabetes['adult_diabetes_pop']=round(df_pop_diabetes.adult_pop*(df_pop_diabetes['diabetes_%']/100))

#Reorder Columns
df_pop_diabetes=df_pop_diabetes[['county', 'state','state_fips', 'county_fips', 'year','total_population', 'adult_pop', 'diabetes_%','adult_diabetes_pop']]

#Print a sample from the dataframe
df_pop_diabetes.head()
# Out:
#              county  state  state_fips  county_fips  year  total_population  \
# 0  aroostook county  Maine          23            3  2004           72959.0
# 1  aroostook county  Maine          23            3  2005           72881.0
# 2  aroostook county  Maine          23            3  2006           72827.0
# 3  aroostook county  Maine          23            3  2007           72711.0
# 4  aroostook county  Maine          23            3  2008           72542.0
#
#    adult_pop  diabetes_%  adult_diabetes_pop
# 0    56542.0         8.7              4919.0
# 1    56482.0         9.3              5253.0
# 2    56440.0        10.2              5757.0
# 3    56350.0        10.2              5748.0
# 4    56219.0        10.5              5903.0

# %% [markdown]
# ## 3. Populous Counties + ACS <a class="anchor" id="3.PopulousCounties+ACS"></a>

# %% [markdown]
# ### 3.1. Prep: ACS Demographic Data <a class="anchor" id="3.1.Prep:ACSDemographicData"></a>

# %%
#Print out any duplicate entires 
df_census[df_census.duplicated(subset=['state','county','year','variable'],keep=False)].sort_values('county').head(5)
# Out:
#            county          state     value  state_fips  county_fips  year  \
# 180    Ada County          Idaho  359035.0          16            1  2006
# 180    Ada County          Idaho  359035.0          16            1  2006
# 84   Adams County       Colorado  414338.0           8            1  2006
# 186  Adams County       Illinois   67221.0          17            1  2006
# 563  Adams County   Pennsylvania  101105.0          42            1  2006
#
#       variable
# 180  total_pop
# 180  total_pop
# 84   total_pop
# 186  total_pop
# 563  total_pop

# %%
#These duplicates are hold over from the api call where population from 2006 was called twice 
#Will drop them now
df_census=df_census.drop_duplicates(subset=['state','county','year','variable'])

# %%
#Fix county in New Mexico with misspelling
df_census.loc[(df_census.county_fips==13) & (df_census.state_fips==35),'county']='Doña Ana County'

#Remove Preceeding white spaces from state names
df_census.state=df_census.state.str.strip()

#Make all county names completely lowercase
df_census.county=df_census.county.str.lower()

#Remove any apostrophes
df_census.county=df_census.county.str.replace("'","")

# %% [markdown]
# ### 3.2. Combine: Demographic & Diabetes Data <a class="anchor" id="3.2.Combine:Demographic&DiabetesData"></a>

# %%
#Ensure that diabetes & census dataframes have same datatype
df_census.dtypes==df_diabetes.dtypes
# Out:
# county         True
# state          True
# value          True
# state_fips     True
# county_fips    True
# year           True
# variable       True
# dtype: bool

# %%
#Save 2004 & 2005 data to its own df, merge again later
df_diabetes=df_diabetes[df_diabetes.year>2005]

# %%
#Merge all dataframes into one
df=pd.concat([df_diabetes,df_census])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 369114 entries, 2 to 839
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   county       369114 non-null  object
#  1   state        369114 non-null  object
#  2   value        368583 non-null  float64
#  3   state_fips   369114 non-null  int64
#  4   county_fips  369114 non-null  int64
#  5   year         369114 non-null  int64
#  6   variable     369114 non-null  object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 22.5+ MB

# %%
#Find any duplicates county/state, year & variable entries
df[df.duplicated(subset=['year','county_fips','state_fips','variable'],keep=False)].sort_values(['county_fips','state_fips','year','variable'])
# Out:
# Empty DataFrame
# Columns: [county, state, value, state_fips, county_fips, year, variable]
# Index: []

# %%
#Pivot table into wide form
df_=pd.pivot(df,index=['state','county','county_fips','state_fips','year'],columns=['variable'],values='value')
df_.reset_index(inplace=True)

#Inspect for missing values
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40390 entries, 0 to 40389
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               40390 non-null  object
#  1   county              40390 non-null  object
#  2   county_fips         40390 non-null  int64
#  3   state_fips          40390 non-null  int64
#  4   year                40390 non-null  int64
#  5   20_24_years         11499 non-null  float64
#  6   25_34_years         11499 non-null  float64
#  7   35_44_years         11499 non-null  float64
#  8   45_54_years         11499 non-null  float64
#  9   55_59_years         11499 non-null  float64
#  10  60_64_years         11499 non-null  float64
#  11  65_74_years         11499 non-null  float64
#  12  75_84_years         11499 non-null  float64
#  13  85_plus_years       11499 non-null  float64
#  14  amer_indian_pop     11499 non-null  float64
#  15  asian_pop           11499 non-null  float64
#  16  black_pop           11499 non-null  float64
#  17  diabetes_%          38641 non-null  float64
#  18  diabetes_%_lower    38641 non-null  float64
#  19  diabetes_%_upper    38641 non-null  float64
#  20  education_bach      11340 non-null  float64
#  21  education_hs        11340 non-null  float64
#  22  female              11499 non-null  float64
#  23  hispanic_pop        11499 non-null  float64
#  24  male                11499 non-null  float64
#  25  median_income       11499 non-null  float64
#  26  other_pop           11499 non-null  float64
#  27  pacific_island_pop  11499 non-null  float64
#  28  total_pop           11499 non-null  float64
#  29  white_pop           11499 non-null  float64
# dtypes: float64(25), int64(3), object(2)
# memory usage: 9.2+ MB

# %%
#Make combined county/state column
df_['county_state']=df_.county+', '+df_.state

# %%
#Search for counties that are missing some entries in the demographic data (not all)
df_na_less=df_.dropna(subset=['total_pop'])
acs_count=pd.DataFrame(df_na_less.groupby('county_state').state.count())

#Isolate counties missing at least 4 of the 14 years worth of total population data from ACS
drop_counties=list(acs_count[acs_count.state<10].index)
acs_count[acs_count.state<10]
# Out:
#                                   state
# county_state
# aguadilla municipio, Puerto Rico      4
# athens county, Ohio                   5
# blue earth county, Minnesota          8
# boone county, Indiana                 3
# broomfield county, Colorado           5
# catoosa county, Georgia               8
# chatham county, North Carolina        8
# crow wing county, Minnesota           1
# franklin county, North Carolina       3
# jackson county, Georgia               3
# kershaw county, South Carolina        3
# lea county, New Mexico                9
# lewis and clark county, Montana       7
# liberty county, Georgia               6
# mason county, Washington              2
# nacogdoches county, Texas             9
# oldham county, Kentucky               4
# otero county, New Mexico              9
# rice county, Minnesota                7
# spalding county, Georgia              3
# tehama county, California             1
# tooele county, Utah                   3
# vega baja municipio, Puerto Rico      1
# walton county, Florida                4
# ward county, North Dakota             7
# wise county, Texas                    3

# %%
#Drop counties from dataframe with at least 4 ACS data years missing
df_=df_[~(df_.county_state.isin(drop_counties))]

# %%
df_.head(100)
# Out:
# variable    state          county  county_fips  state_fips  year  20_24_years  \
# 0         Alabama  autauga county            1           1  2006          NaN
# 1         Alabama  autauga county            1           1  2007          NaN
# 2         Alabama  autauga county            1           1  2008          NaN
# 3         Alabama  autauga county            1           1  2009          NaN
# 4         Alabama  autauga county            1           1  2010          NaN
# 5         Alabama  autauga county            1           1  2011          NaN
# 6         Alabama  autauga county            1           1  2012          NaN
# 7         Alabama  autauga county            1           1  2013          NaN
# 8         Alabama  autauga county            1           1  2014          NaN
# 9         Alabama  autauga county            1           1  2015          NaN
# 10        Alabama  autauga county            1           1  2016          NaN
# 11        Alabama  autauga county            1           1  2017          NaN
# 12        Alabama  baldwin county            3           1  2006      11242.0
# 13        Alabama  baldwin county            3           1  2007       9547.0
# 14        Alabama  baldwin county            3           1  2008       8634.0
# 15        Alabama  baldwin county            3           1  2009       9665.0
# 16        Alabama  baldwin county            3           1  2010       8429.0
# 17        Alabama  baldwin county            3           1  2011       9079.0
# 18        Alabama  baldwin county            3           1  2012      11010.0
# 19        Alabama  baldwin county            3           1  2013      12329.0
# 20        Alabama  baldwin county            3           1  2014       9808.0
# 21        Alabama  baldwin county            3           1  2015      10338.0
# 22        Alabama  baldwin county            3           1  2016      10454.0
# 23        Alabama  baldwin county            3           1  2017      10280.0
# 24        Alabama  baldwin county            3           1  2018      10426.0
# 25        Alabama  baldwin county            3           1  2019      11292.0
# 26        Alabama  barbour county            5           1  2006          NaN
# 27        Alabama  barbour county            5           1  2007          NaN
# 28        Alabama  barbour county            5           1  2008          NaN
# 29        Alabama  barbour county            5           1  2009          NaN
# 30        Alabama  barbour county            5           1  2010          NaN
# 31        Alabama  barbour county            5           1  2011          NaN
# 32        Alabama  barbour county            5           1  2012          NaN
# 33        Alabama  barbour county            5           1  2013          NaN
# 34        Alabama  barbour county            5           1  2014          NaN
# 35        Alabama  barbour county            5           1  2015          NaN
# 36        Alabama  barbour county            5           1  2016          NaN
# 37        Alabama  barbour county            5           1  2017          NaN
# 38        Alabama     bibb county            7           1  2006          NaN
# 39        Alabama     bibb county            7           1  2007          NaN
# 40        Alabama     bibb county            7           1  2008          NaN
# 41        Alabama     bibb county            7           1  2009          NaN
# 42        Alabama     bibb county            7           1  2010          NaN
# 43        Alabama     bibb county            7           1  2011          NaN
# 44        Alabama     bibb county            7           1  2012          NaN
# 45        Alabama     bibb county            7           1  2013          NaN
# 46        Alabama     bibb county            7           1  2014          NaN
# 47        Alabama     bibb county            7           1  2015          NaN
# 48        Alabama     bibb county            7           1  2016          NaN
# 49        Alabama     bibb county            7           1  2017          NaN
# 50        Alabama   blount county            9           1  2006          NaN
# 51        Alabama   blount county            9           1  2007          NaN
# 52        Alabama   blount county            9           1  2008          NaN
# 53        Alabama   blount county            9           1  2009          NaN
# 54        Alabama   blount county            9           1  2010          NaN
# 55        Alabama   blount county            9           1  2011          NaN
# 56        Alabama   blount county            9           1  2012          NaN
# 57        Alabama   blount county            9           1  2013          NaN
# 58        Alabama   blount county            9           1  2014          NaN
# 59        Alabama   blount county            9           1  2015          NaN
# 60        Alabama   blount county            9           1  2016          NaN
# 61        Alabama   blount county            9           1  2017          NaN
# 62        Alabama  bullock county           11           1  2006          NaN
# 63        Alabama  bullock county           11           1  2007          NaN
# 64        Alabama  bullock county           11           1  2008          NaN
# 65        Alabama  bullock county           11           1  2009          NaN
# 66        Alabama  bullock county           11           1  2010          NaN
# 67        Alabama  bullock county           11           1  2011          NaN
# 68        Alabama  bullock county           11           1  2012          NaN
# 69        Alabama  bullock county           11           1  2013          NaN
# 70        Alabama  bullock county           11           1  2014          NaN
# 71        Alabama  bullock county           11           1  2015          NaN
# 72        Alabama  bullock county           11           1  2016          NaN
# 73        Alabama  bullock county           11           1  2017          NaN
# 74        Alabama   butler county           13           1  2006          NaN
# 75        Alabama   butler county           13           1  2007          NaN
# 76        Alabama   butler county           13           1  2008          NaN
# 77        Alabama   butler county           13           1  2009          NaN
# 78        Alabama   butler county           13           1  2010          NaN
# 79        Alabama   butler county           13           1  2011          NaN
# 80        Alabama   butler county           13           1  2012          NaN
# 81        Alabama   butler county           13           1  2013          NaN
# 82        Alabama   butler county           13           1  2014          NaN
# 83        Alabama   butler county           13           1  2015          NaN
# 84        Alabama   butler county           13           1  2016          NaN
# 85        Alabama   butler county           13           1  2017          NaN
# 86        Alabama  calhoun county           15           1  2006       8480.0
# 87        Alabama  calhoun county           15           1  2007       7553.0
# 88        Alabama  calhoun county           15           1  2008       7929.0
# 89        Alabama  calhoun county           15           1  2009       7046.0
# 90        Alabama  calhoun county           15           1  2010       8459.0
# 91        Alabama  calhoun county           15           1  2011       9209.0
# 92        Alabama  calhoun county           15           1  2012       9575.0
# 93        Alabama  calhoun county           15           1  2013       8383.0
# 94        Alabama  calhoun county           15           1  2014       7784.0
# 95        Alabama  calhoun county           15           1  2015       8074.0
# 96        Alabama  calhoun county           15           1  2016       8005.0
# 97        Alabama  calhoun county           15           1  2017       6906.0
# 98        Alabama  calhoun county           15           1  2018       7451.0
# 99        Alabama  calhoun county           15           1  2019       6973.0
#
# variable  25_34_years  35_44_years  45_54_years  55_59_years  60_64_years  \
# 0                 NaN          NaN          NaN          NaN          NaN
# 1                 NaN          NaN          NaN          NaN          NaN
# 2                 NaN          NaN          NaN          NaN          NaN
# 3                 NaN          NaN          NaN          NaN          NaN
# 4                 NaN          NaN          NaN          NaN          NaN
# 5                 NaN          NaN          NaN          NaN          NaN
# 6                 NaN          NaN          NaN          NaN          NaN
# 7                 NaN          NaN          NaN          NaN          NaN
# 8                 NaN          NaN          NaN          NaN          NaN
# 9                 NaN          NaN          NaN          NaN          NaN
# 10                NaN          NaN          NaN          NaN          NaN
# 11                NaN          NaN          NaN          NaN          NaN
# 12            22331.0      23589.0      23997.0      10334.0       9482.0
# 13            22958.0      23024.0      24093.0      10157.0       9268.0
# 14            25220.0      23431.0      23540.0       9633.0      10164.0
# 15            22686.0      23163.0      25771.0      11352.0      11163.0
# 16            21568.0      23611.0      27276.0      12278.0      12579.0
# 17            23402.0      23642.0      26857.0      11909.0      13776.0
# 18            22639.0      22547.0      28378.0      13354.0      12680.0
# 19            23066.0      24115.0      25400.0      12901.0      14431.0
# 20            23464.0      24656.0      26959.0      13702.0      14025.0
# 21            23734.0      25431.0      27309.0      12895.0      14388.0
# 22            24663.0      23384.0      28689.0      14891.0      14739.0
# 23            25425.0      26549.0      27320.0      14819.0      15422.0
# 24            23498.0      25990.0      30117.0      16569.0      15074.0
# 25            24401.0      28477.0      27285.0      16425.0      15441.0
# 26                NaN          NaN          NaN          NaN          NaN
# 27                NaN          NaN          NaN          NaN          NaN
# 28                NaN          NaN          NaN          NaN          NaN
# 29                NaN          NaN          NaN          NaN          NaN
# 30                NaN          NaN          NaN          NaN          NaN
# 31                NaN          NaN          NaN          NaN          NaN
# 32                NaN          NaN          NaN          NaN          NaN
# 33                NaN          NaN          NaN          NaN          NaN
# 34                NaN          NaN          NaN          NaN          NaN
# 35                NaN          NaN          NaN          NaN          NaN
# 36                NaN          NaN          NaN          NaN          NaN
# 37                NaN          NaN          NaN          NaN          NaN
# 38                NaN          NaN          NaN          NaN          NaN
# 39                NaN          NaN          NaN          NaN          NaN
# 40                NaN          NaN          NaN          NaN          NaN
# 41                NaN          NaN          NaN          NaN          NaN
# 42                NaN          NaN          NaN          NaN          NaN
# 43                NaN          NaN          NaN          NaN          NaN
# 44                NaN          NaN          NaN          NaN          NaN
# 45                NaN          NaN          NaN          NaN          NaN
# 46                NaN          NaN          NaN          NaN          NaN
# 47                NaN          NaN          NaN          NaN          NaN
# 48                NaN          NaN          NaN          NaN          NaN
# 49                NaN          NaN          NaN          NaN          NaN
# 50                NaN          NaN          NaN          NaN          NaN
# 51                NaN          NaN          NaN          NaN          NaN
# 52                NaN          NaN          NaN          NaN          NaN
# 53                NaN          NaN          NaN          NaN          NaN
# 54                NaN          NaN          NaN          NaN          NaN
# 55                NaN          NaN          NaN          NaN          NaN
# 56                NaN          NaN          NaN          NaN          NaN
# 57                NaN          NaN          NaN          NaN          NaN
# 58                NaN          NaN          NaN          NaN          NaN
# 59                NaN          NaN          NaN          NaN          NaN
# 60                NaN          NaN          NaN          NaN          NaN
# 61                NaN          NaN          NaN          NaN          NaN
# 62                NaN          NaN          NaN          NaN          NaN
# 63                NaN          NaN          NaN          NaN          NaN
# 64                NaN          NaN          NaN          NaN          NaN
# 65                NaN          NaN          NaN          NaN          NaN
# 66                NaN          NaN          NaN          NaN          NaN
# 67                NaN          NaN          NaN          NaN          NaN
# 68                NaN          NaN          NaN          NaN          NaN
# 69                NaN          NaN          NaN          NaN          NaN
# 70                NaN          NaN          NaN          NaN          NaN
# 71                NaN          NaN          NaN          NaN          NaN
# 72                NaN          NaN          NaN          NaN          NaN
# 73                NaN          NaN          NaN          NaN          NaN
# 74                NaN          NaN          NaN          NaN          NaN
# 75                NaN          NaN          NaN          NaN          NaN
# 76                NaN          NaN          NaN          NaN          NaN
# 77                NaN          NaN          NaN          NaN          NaN
# 78                NaN          NaN          NaN          NaN          NaN
# 79                NaN          NaN          NaN          NaN          NaN
# 80                NaN          NaN          NaN          NaN          NaN
# 81                NaN          NaN          NaN          NaN          NaN
# 82                NaN          NaN          NaN          NaN          NaN
# 83                NaN          NaN          NaN          NaN          NaN
# 84                NaN          NaN          NaN          NaN          NaN
# 85                NaN          NaN          NaN          NaN          NaN
# 86            13952.0      15420.0      16350.0       7325.0       5396.0
# 87            13386.0      15047.0      16324.0       8209.0       6033.0
# 88            13396.0      15479.0      16579.0       7746.0       6417.0
# 89            15637.0      13674.0      16109.0       8342.0       5886.0
# 90            14368.0      15170.0      16674.0       8042.0       7126.0
# 91            14167.0      14429.0      16782.0       7518.0       7826.0
# 92            14117.0      14856.0      15601.0       9003.0       6871.0
# 93            14869.0      15115.0      15139.0       7577.0       7734.0
# 94            14708.0      14750.0      15290.0       7064.0       8647.0
# 95            14555.0      14278.0      14849.0       9019.0       7157.0
# 96            14623.0      14083.0      14990.0       7457.0       8103.0
# 97            15103.0      14286.0      14449.0       7419.0       8350.0
# 98            16273.0      12608.0      13616.0       8305.0       7855.0
# 99            14981.0      14394.0      13354.0       7389.0       8410.0
#
# variable  65_74_years  75_84_years  85_plus_years  amer_indian_pop  \
# 0                 NaN          NaN            NaN              NaN
# 1                 NaN          NaN            NaN              NaN
# 2                 NaN          NaN            NaN              NaN
# 3                 NaN          NaN            NaN              NaN
# 4                 NaN          NaN            NaN              NaN
# 5                 NaN          NaN            NaN              NaN
# 6                 NaN          NaN            NaN              NaN
# 7                 NaN          NaN            NaN              NaN
# 8                 NaN          NaN            NaN              NaN
# 9                 NaN          NaN            NaN              NaN
# 10                NaN          NaN            NaN              NaN
# 11                NaN          NaN            NaN              NaN
# 12            14128.0      10628.0         2238.0           1967.0
# 13            14610.0      10467.0         3113.0           1584.0
# 14            15011.0      10973.0         2829.0           3111.0
# 15            17380.0       9655.0         3664.0           1753.0
# 16            18297.0       9185.0         3175.0           2360.0
# 17            18366.0       9574.0         3688.0           2368.0
# 18            20310.0      10143.0         3382.0           2460.0
# 19            20992.0       9867.0         4244.0            609.0
# 20            22395.0      11579.0         3808.0           2965.0
# 21            24751.0      10536.0         4694.0           2837.0
# 22            24102.0      12609.0         3910.0           3489.0
# 23            25551.0      12919.0         4032.0           2759.0
# 24            27152.0      13464.0         3827.0           3442.0
# 25            28918.0      14425.0         4345.0           4474.0
# 26                NaN          NaN            NaN              NaN
# 27                NaN          NaN            NaN              NaN
# 28                NaN          NaN            NaN              NaN
# 29                NaN          NaN            NaN              NaN
# 30                NaN          NaN            NaN              NaN
# 31                NaN          NaN            NaN              NaN
# 32                NaN          NaN            NaN              NaN
# 33                NaN          NaN            NaN              NaN
# 34                NaN          NaN            NaN              NaN
# 35                NaN          NaN            NaN              NaN
# 36                NaN          NaN            NaN              NaN
# 37                NaN          NaN            NaN              NaN
# 38                NaN          NaN            NaN              NaN
# 39                NaN          NaN            NaN              NaN
# 40                NaN          NaN            NaN              NaN
# 41                NaN          NaN            NaN              NaN
# 42                NaN          NaN            NaN              NaN
# 43                NaN          NaN            NaN              NaN
# 44                NaN          NaN            NaN              NaN
# 45                NaN          NaN            NaN              NaN
# 46                NaN          NaN            NaN              NaN
# 47                NaN          NaN            NaN              NaN
# 48                NaN          NaN            NaN              NaN
# 49                NaN          NaN            NaN              NaN
# 50                NaN          NaN            NaN              NaN
# 51                NaN          NaN            NaN              NaN
# 52                NaN          NaN            NaN              NaN
# 53                NaN          NaN            NaN              NaN
# 54                NaN          NaN            NaN              NaN
# 55                NaN          NaN            NaN              NaN
# 56                NaN          NaN            NaN              NaN
# 57                NaN          NaN            NaN              NaN
# 58                NaN          NaN            NaN              NaN
# 59                NaN          NaN            NaN              NaN
# 60                NaN          NaN            NaN              NaN
# 61                NaN          NaN            NaN              NaN
# 62                NaN          NaN            NaN              NaN
# 63                NaN          NaN            NaN              NaN
# 64                NaN          NaN            NaN              NaN
# 65                NaN          NaN            NaN              NaN
# 66                NaN          NaN            NaN              NaN
# 67                NaN          NaN            NaN              NaN
# 68                NaN          NaN            NaN              NaN
# 69                NaN          NaN            NaN              NaN
# 70                NaN          NaN            NaN              NaN
# 71                NaN          NaN            NaN              NaN
# 72                NaN          NaN            NaN              NaN
# 73                NaN          NaN            NaN              NaN
# 74                NaN          NaN            NaN              NaN
# 75                NaN          NaN            NaN              NaN
# 76                NaN          NaN            NaN              NaN
# 77                NaN          NaN            NaN              NaN
# 78                NaN          NaN            NaN              NaN
# 79                NaN          NaN            NaN              NaN
# 80                NaN          NaN            NaN              NaN
# 81                NaN          NaN            NaN              NaN
# 82                NaN          NaN            NaN              NaN
# 83                NaN          NaN            NaN              NaN
# 84                NaN          NaN            NaN              NaN
# 85                NaN          NaN            NaN              NaN
# 86             8720.0       5324.0         2689.0            943.0
# 87             8605.0       6055.0         1659.0            700.0
# 88             8291.0       5895.0         2274.0           1055.0
# 89             9052.0       6620.0         1555.0           1004.0
# 90             9385.0       6093.0         1652.0            972.0
# 91             9553.0       6166.0         1706.0           1213.0
# 92             9951.0       5318.0         2267.0           1089.0
# 93            10548.0       5688.0         1695.0            968.0
# 94            10914.0       5974.0         1655.0           1154.0
# 95            10936.0       5779.0         1814.0           1541.0
# 96            11229.0       5570.0         2163.0           1663.0
# 97            11954.0       5539.0         2482.0            757.0
# 98            12240.0       6514.0         1761.0            489.0
# 99            12098.0       6595.0         1863.0           1198.0
#
# variable    asian_pop  black_pop  diabetes_%  diabetes_%_lower  \
# 0                 NaN        NaN        11.0               8.5
# 1                 NaN        NaN        11.2               8.6
# 2                 NaN        NaN        10.9               8.5
# 3                 NaN        NaN        11.7               9.2
# 4                 NaN        NaN        11.2               8.8
# 5                 NaN        NaN        11.3               8.9
# 6                 NaN        NaN        11.1               8.8
# 7                 NaN        NaN        11.9               9.6
# 8                 NaN        NaN        11.4               9.3
# 9                 NaN        NaN        13.0              10.2
# 10                NaN        NaN         9.9               6.9
# 11                NaN        NaN        11.4               8.3
# 12              948.0    17173.0         7.8               6.2
# 13              608.0    18004.0         8.1               6.7
# 14             1572.0    17590.0         8.6               7.1
# 15             1483.0    18337.0         9.9               8.5
# 16             1740.0    18068.0        10.2               8.7
# 17             1784.0    18824.0         9.8               8.3
# 18             2314.0    19448.0         9.1               7.6
# 19             2188.0    21324.0         8.8               7.3
# 20             2388.0    20062.0         9.3               8.0
# 21              592.0    23329.0         9.3               8.0
# 22             2831.0    20200.0         8.5               7.1
# 23             3076.0    20716.0         8.2               6.9
# 24             3143.0    20781.0         NaN               NaN
# 25             3326.0    20964.0         NaN               NaN
# 26                NaN        NaN        11.5               8.9
# 27                NaN        NaN        12.3               9.5
# 28                NaN        NaN        12.9              10.2
# 29                NaN        NaN        13.2              10.7
# 30                NaN        NaN        13.0              10.6
# 31                NaN        NaN        13.6              10.8
# 32                NaN        NaN        14.9              11.9
# 33                NaN        NaN        16.9              13.5
# 34                NaN        NaN        16.5              13.4
# 35                NaN        NaN        16.2              13.0
# 36                NaN        NaN        15.7              10.5
# 37                NaN        NaN        15.1               9.9
# 38                NaN        NaN        10.7               8.1
# 39                NaN        NaN        11.3               8.8
# 40                NaN        NaN        10.6               8.5
# 41                NaN        NaN        11.2               8.9
# 42                NaN        NaN        10.6               8.2
# 43                NaN        NaN        12.0               9.3
# 44                NaN        NaN        12.4               9.7
# 45                NaN        NaN        13.8              10.6
# 46                NaN        NaN        13.5              10.7
# 47                NaN        NaN        13.7              10.8
# 48                NaN        NaN        13.3               8.4
# 49                NaN        NaN        12.2               7.8
# 50                NaN        NaN         9.0               6.8
# 51                NaN        NaN         9.6               7.2
# 52                NaN        NaN        10.7               8.3
# 53                NaN        NaN        11.5               9.0
# 54                NaN        NaN        12.6               9.8
# 55                NaN        NaN        11.8               9.1
# 56                NaN        NaN        12.2               9.5
# 57                NaN        NaN        12.3               9.5
# 58                NaN        NaN        12.5               9.9
# 59                NaN        NaN        12.4               9.9
# 60                NaN        NaN        14.9              10.8
# 61                NaN        NaN        12.2               8.9
# 62                NaN        NaN        14.0              10.6
# 63                NaN        NaN        14.6              11.2
# 64                NaN        NaN        15.7              12.2
# 65                NaN        NaN        15.6              12.2
# 66                NaN        NaN        16.1              12.4
# 67                NaN        NaN        16.2              12.3
# 68                NaN        NaN        17.2              13.2
# 69                NaN        NaN        18.1              13.1
# 70                NaN        NaN        18.0              13.8
# 71                NaN        NaN        18.3              13.4
# 72                NaN        NaN        22.4              11.8
# 73                NaN        NaN        27.9              14.9
# 74                NaN        NaN        11.2               8.5
# 75                NaN        NaN        12.7               9.9
# 76                NaN        NaN        13.5              11.0
# 77                NaN        NaN        14.6              11.9
# 78                NaN        NaN        13.9              11.3
# 79                NaN        NaN        14.0              11.3
# 80                NaN        NaN        14.2              11.3
# 81                NaN        NaN        15.4              12.1
# 82                NaN        NaN        15.1              12.0
# 83                NaN        NaN        15.4              12.1
# 84                NaN        NaN        16.9              11.4
# 85                NaN        NaN        17.0              11.0
# 86              799.0    23161.0        11.1               9.2
# 87             1207.0    23374.0        12.6              10.6
# 88             1225.0    23240.0        13.4              11.6
# 89              751.0    23544.0        12.9              11.1
# 90             1086.0    25510.0        12.7              10.9
# 91              412.0    26417.0        12.1              10.3
# 92             1344.0    25874.0        13.1              11.0
# 93             1207.0    25480.0        13.4              11.4
# 94       -999999999.0    25854.0        14.6              12.6
# 95             1703.0    25426.0        14.5              12.6
# 96             1362.0    25043.0        15.6              13.0
# 97             1448.0    25331.0        15.2              12.5
# 98             1594.0    25595.0         NaN               NaN
# 99              507.0    26846.0         NaN               NaN
#
# variable  diabetes_%_upper  education_bach  education_hs    female  \
# 0                     13.9             NaN           NaN       NaN
# 1                     14.1             NaN           NaN       NaN
# 2                     13.5             NaN           NaN       NaN
# 3                     14.7             NaN           NaN       NaN
# 4                     13.9             NaN           NaN       NaN
# 5                     14.1             NaN           NaN       NaN
# 6                     13.8             NaN           NaN       NaN
# 7                     14.6             NaN           NaN       NaN
# 8                     13.9             NaN           NaN       NaN
# 9                     16.1             NaN           NaN       NaN
# 10                    14.2             NaN           NaN       NaN
# 11                    15.2             NaN           NaN       NaN
# 12                     9.6            25.8          86.7   85849.0
# 13                     9.7            26.4          88.3   87601.0
# 14                    10.0            29.5          87.9   88477.0
# 15                    11.5            26.5          89.2   92010.0
# 16                    11.9            27.2          87.7   93265.0
# 17                    11.4            28.3          90.4   96615.0
# 18                    10.6            29.1          89.2   97209.0
# 19                    10.2            29.0          90.6  100635.0
# 20                    10.8            30.5          89.0  101827.0
# 21                    10.7            29.5          90.8  103479.0
# 22                    10.2            29.6          89.9  107661.0
# 23                     9.7            33.6          89.3  107930.0
# 24                     NaN            31.4          90.2  112585.0
# 25                     NaN            32.2          90.5  114042.0
# 26                    14.5             NaN           NaN       NaN
# 27                    15.2             NaN           NaN       NaN
# 28                    15.7             NaN           NaN       NaN
# 29                    15.9             NaN           NaN       NaN
# 30                    15.9             NaN           NaN       NaN
# 31                    16.7             NaN           NaN       NaN
# 32                    18.4             NaN           NaN       NaN
# 33                    21.2             NaN           NaN       NaN
# 34                    20.0             NaN           NaN       NaN
# 35                    19.4             NaN           NaN       NaN
# 36                    22.3             NaN           NaN       NaN
# 37                    22.7             NaN           NaN       NaN
# 38                    13.9             NaN           NaN       NaN
# 39                    14.4             NaN           NaN       NaN
# 40                    13.1             NaN           NaN       NaN
# 41                    14.0             NaN           NaN       NaN
# 42                    13.3             NaN           NaN       NaN
# 43                    15.2             NaN           NaN       NaN
# 44                    15.5             NaN           NaN       NaN
# 45                    17.3             NaN           NaN       NaN
# 46                    17.0             NaN           NaN       NaN
# 47                    17.5             NaN           NaN       NaN
# 48                    19.8             NaN           NaN       NaN
# 49                    18.5             NaN           NaN       NaN
# 50                    11.8             NaN           NaN       NaN
# 51                    12.4             NaN           NaN       NaN
# 52                    13.6             NaN           NaN       NaN
# 53                    14.6             NaN           NaN       NaN
# 54                    15.7             NaN           NaN       NaN
# 55                    14.9             NaN           NaN       NaN
# 56                    15.3             NaN           NaN       NaN
# 57                    15.1             NaN           NaN       NaN
# 58                    15.3             NaN           NaN       NaN
# 59                    15.2             NaN           NaN       NaN
# 60                    20.0             NaN           NaN       NaN
# 61                    16.6             NaN           NaN       NaN
# 62                    17.8             NaN           NaN       NaN
# 63                    18.6             NaN           NaN       NaN
# 64                    19.6             NaN           NaN       NaN
# 65                    19.6             NaN           NaN       NaN
# 66                    20.4             NaN           NaN       NaN
# 67                    20.9             NaN           NaN       NaN
# 68                    22.4             NaN           NaN       NaN
# 69                    23.7             NaN           NaN       NaN
# 70                    23.0             NaN           NaN       NaN
# 71                    23.6             NaN           NaN       NaN
# 72                    37.7             NaN           NaN       NaN
# 73                    43.7             NaN           NaN       NaN
# 74                    14.4             NaN           NaN       NaN
# 75                    15.7             NaN           NaN       NaN
# 76                    16.5             NaN           NaN       NaN
# 77                    17.5             NaN           NaN       NaN
# 78                    16.9             NaN           NaN       NaN
# 79                    17.2             NaN           NaN       NaN
# 80                    17.7             NaN           NaN       NaN
# 81                    19.3             NaN           NaN       NaN
# 82                    18.8             NaN           NaN       NaN
# 83                    19.0             NaN           NaN       NaN
# 84                    23.5             NaN           NaN       NaN
# 85                    23.9             NaN           NaN       NaN
# 86                    13.1            18.6          77.8   58574.0
# 87                    14.9            15.2          78.4   58856.0
# 88                    15.4            15.7          80.4   59136.0
# 89                    14.8            17.0          77.8   59672.0
# 90                    14.7            14.7          78.3   62056.0
# 91                    14.0            15.2          75.8   61197.0
# 92                    15.3            16.9          79.8   61154.0
# 93                    15.4            15.0          80.3   60135.0
# 94                    16.9            18.8          83.3   60467.0
# 95                    16.7            17.3          82.0   59799.0
# 96                    18.3            16.5          82.2   59120.0
# 97                    18.2            19.3          85.3   59389.0
# 98                     NaN            18.0          84.7   59223.0
# 99                     NaN            19.3          84.6   59320.0
#
# variable  hispanic_pop      male  median_income    other_pop  \
# 0                  NaN       NaN            NaN          NaN
# 1                  NaN       NaN            NaN          NaN
# 2                  NaN       NaN            NaN          NaN
# 3                  NaN       NaN            NaN          NaN
# 4                  NaN       NaN            NaN          NaN
# 5                  NaN       NaN            NaN          NaN
# 6                  NaN       NaN            NaN          NaN
# 7                  NaN       NaN            NaN          NaN
# 8                  NaN       NaN            NaN          NaN
# 9                  NaN       NaN            NaN          NaN
# 10                 NaN       NaN            NaN          NaN
# 11                 NaN       NaN            NaN          NaN
# 12              4176.0   83313.0        44878.0       3327.0
# 13              4621.0   84168.0        49119.0       2504.0
# 14              5020.0   85962.0        52320.0       2640.0
# 15              5949.0   87868.0        48487.0       3564.0
# 16              8078.0   89930.0        47502.0       1819.0
# 17              8457.0   90102.0        50900.0       1721.0
# 18              8737.0   93581.0        48378.0       2333.0
# 19              8949.0   94905.0        44874.0       2294.0
# 20              9130.0   98284.0        48461.0       3223.0
# 21              9268.0  100230.0        52003.0       2235.0
# 22              9211.0  100902.0        56732.0       2025.0
# 23              9675.0  104698.0        55342.0       2207.0
# 24             10132.0  105437.0        56813.0       2798.0
# 25             10534.0  109192.0        56439.0       4685.0
# 26                 NaN       NaN            NaN          NaN
# 27                 NaN       NaN            NaN          NaN
# 28                 NaN       NaN            NaN          NaN
# 29                 NaN       NaN            NaN          NaN
# 30                 NaN       NaN            NaN          NaN
# 31                 NaN       NaN            NaN          NaN
# 32                 NaN       NaN            NaN          NaN
# 33                 NaN       NaN            NaN          NaN
# 34                 NaN       NaN            NaN          NaN
# 35                 NaN       NaN            NaN          NaN
# 36                 NaN       NaN            NaN          NaN
# 37                 NaN       NaN            NaN          NaN
# 38                 NaN       NaN            NaN          NaN
# 39                 NaN       NaN            NaN          NaN
# 40                 NaN       NaN            NaN          NaN
# 41                 NaN       NaN            NaN          NaN
# 42                 NaN       NaN            NaN          NaN
# 43                 NaN       NaN            NaN          NaN
# 44                 NaN       NaN            NaN          NaN
# 45                 NaN       NaN            NaN          NaN
# 46                 NaN       NaN            NaN          NaN
# 47                 NaN       NaN            NaN          NaN
# 48                 NaN       NaN            NaN          NaN
# 49                 NaN       NaN            NaN          NaN
# 50                 NaN       NaN            NaN          NaN
# 51                 NaN       NaN            NaN          NaN
# 52                 NaN       NaN            NaN          NaN
# 53                 NaN       NaN            NaN          NaN
# 54                 NaN       NaN            NaN          NaN
# 55                 NaN       NaN            NaN          NaN
# 56                 NaN       NaN            NaN          NaN
# 57                 NaN       NaN            NaN          NaN
# 58                 NaN       NaN            NaN          NaN
# 59                 NaN       NaN            NaN          NaN
# 60                 NaN       NaN            NaN          NaN
# 61                 NaN       NaN            NaN          NaN
# 62                 NaN       NaN            NaN          NaN
# 63                 NaN       NaN            NaN          NaN
# 64                 NaN       NaN            NaN          NaN
# 65                 NaN       NaN            NaN          NaN
# 66                 NaN       NaN            NaN          NaN
# 67                 NaN       NaN            NaN          NaN
# 68                 NaN       NaN            NaN          NaN
# 69                 NaN       NaN            NaN          NaN
# 70                 NaN       NaN            NaN          NaN
# 71                 NaN       NaN            NaN          NaN
# 72                 NaN       NaN            NaN          NaN
# 73                 NaN       NaN            NaN          NaN
# 74                 NaN       NaN            NaN          NaN
# 75                 NaN       NaN            NaN          NaN
# 76                 NaN       NaN            NaN          NaN
# 77                 NaN       NaN            NaN          NaN
# 78                 NaN       NaN            NaN          NaN
# 79                 NaN       NaN            NaN          NaN
# 80                 NaN       NaN            NaN          NaN
# 81                 NaN       NaN            NaN          NaN
# 82                 NaN       NaN            NaN          NaN
# 83                 NaN       NaN            NaN          NaN
# 84                 NaN       NaN            NaN          NaN
# 85                 NaN       NaN            NaN          NaN
# 86              2399.0   54329.0        36241.0       1068.0
# 87              2572.0   54247.0        37074.0       1341.0
# 88              2665.0   54283.0        40056.0       1047.0
# 89              3008.0   54409.0        36527.0       2184.0
# 90              3981.0   56454.0        36675.0       2799.0
# 91              4032.0   56600.0        39037.0       1790.0
# 92              4068.0   56142.0        39169.0 -999999999.0
# 93              4066.0   56601.0        36205.0       1356.0
# 94              4089.0   55449.0        41428.0 -999999999.0
# 95              4179.0   55821.0        42346.0       1871.0
# 96              4100.0   55491.0        41687.0       2248.0
# 97              4301.0   55339.0        46763.0       2108.0
# 98              4469.0   55054.0        45818.0       2024.0
# 99              4614.0   54285.0        48156.0       3186.0
#
# variable  pacific_island_pop  total_pop  white_pop             county_state
# 0                        NaN        NaN        NaN  autauga county, Alabama
# 1                        NaN        NaN        NaN  autauga county, Alabama
# 2                        NaN        NaN        NaN  autauga county, Alabama
# 3                        NaN        NaN        NaN  autauga county, Alabama
# 4                        NaN        NaN        NaN  autauga county, Alabama
# 5                        NaN        NaN        NaN  autauga county, Alabama
# 6                        NaN        NaN        NaN  autauga county, Alabama
# 7                        NaN        NaN        NaN  autauga county, Alabama
# 8                        NaN        NaN        NaN  autauga county, Alabama
# 9                        NaN        NaN        NaN  autauga county, Alabama
# 10                       NaN        NaN        NaN  autauga county, Alabama
# 11                       NaN        NaN        NaN  autauga county, Alabama
# 12              -999999999.0   169162.0   148241.0  baldwin county, Alabama
# 13              -999999999.0   171769.0   150177.0  baldwin county, Alabama
# 14              -999999999.0   174439.0   152496.0  baldwin county, Alabama
# 15              -999999999.0   179878.0   156301.0  baldwin county, Alabama
# 16              -999999999.0   183195.0   162119.0  baldwin county, Alabama
# 17              -999999999.0   186717.0   164372.0  baldwin county, Alabama
# 18              -999999999.0   190790.0   169234.0  baldwin county, Alabama
# 19              -999999999.0   195540.0   171376.0  baldwin county, Alabama
# 20              -999999999.0   200111.0   175327.0  baldwin county, Alabama
# 21              -999999999.0   203709.0   176890.0  baldwin county, Alabama
# 22              -999999999.0   208563.0   185425.0  baldwin county, Alabama
# 23              -999999999.0   212628.0   186019.0  baldwin county, Alabama
# 24              -999999999.0   218022.0   191157.0  baldwin county, Alabama
# 25              -999999999.0   223234.0   195623.0  baldwin county, Alabama
# 26                       NaN        NaN        NaN  barbour county, Alabama
# 27                       NaN        NaN        NaN  barbour county, Alabama
# 28                       NaN        NaN        NaN  barbour county, Alabama
# 29                       NaN        NaN        NaN  barbour county, Alabama
# 30                       NaN        NaN        NaN  barbour county, Alabama
# 31                       NaN        NaN        NaN  barbour county, Alabama
# 32                       NaN        NaN        NaN  barbour county, Alabama
# 33                       NaN        NaN        NaN  barbour county, Alabama
# 34                       NaN        NaN        NaN  barbour county, Alabama
# 35                       NaN        NaN        NaN  barbour county, Alabama
# 36                       NaN        NaN        NaN  barbour county, Alabama
# 37                       NaN        NaN        NaN  barbour county, Alabama
# 38                       NaN        NaN        NaN     bibb county, Alabama
# 39                       NaN        NaN        NaN     bibb county, Alabama
# 40                       NaN        NaN        NaN     bibb county, Alabama
# 41                       NaN        NaN        NaN     bibb county, Alabama
# 42                       NaN        NaN        NaN     bibb county, Alabama
# 43                       NaN        NaN        NaN     bibb county, Alabama
# 44                       NaN        NaN        NaN     bibb county, Alabama
# 45                       NaN        NaN        NaN     bibb county, Alabama
# 46                       NaN        NaN        NaN     bibb county, Alabama
# 47                       NaN        NaN        NaN     bibb county, Alabama
# 48                       NaN        NaN        NaN     bibb county, Alabama
# 49                       NaN        NaN        NaN     bibb county, Alabama
# 50                       NaN        NaN        NaN   blount county, Alabama
# 51                       NaN        NaN        NaN   blount county, Alabama
# 52                       NaN        NaN        NaN   blount county, Alabama
# 53                       NaN        NaN        NaN   blount county, Alabama
# 54                       NaN        NaN        NaN   blount county, Alabama
# 55                       NaN        NaN        NaN   blount county, Alabama
# 56                       NaN        NaN        NaN   blount county, Alabama
# 57                       NaN        NaN        NaN   blount county, Alabama
# 58                       NaN        NaN        NaN   blount county, Alabama
# 59                       NaN        NaN        NaN   blount county, Alabama
# 60                       NaN        NaN        NaN   blount county, Alabama
# 61                       NaN        NaN        NaN   blount county, Alabama
# 62                       NaN        NaN        NaN  bullock county, Alabama
# 63                       NaN        NaN        NaN  bullock county, Alabama
# 64                       NaN        NaN        NaN  bullock county, Alabama
# 65                       NaN        NaN        NaN  bullock county, Alabama
# 66                       NaN        NaN        NaN  bullock county, Alabama
# 67                       NaN        NaN        NaN  bullock county, Alabama
# 68                       NaN        NaN        NaN  bullock county, Alabama
# 69                       NaN        NaN        NaN  bullock county, Alabama
# 70                       NaN        NaN        NaN  bullock county, Alabama
# 71                       NaN        NaN        NaN  bullock county, Alabama
# 72                       NaN        NaN        NaN  bullock county, Alabama
# 73                       NaN        NaN        NaN  bullock county, Alabama
# 74                       NaN        NaN        NaN   butler county, Alabama
# 75                       NaN        NaN        NaN   butler county, Alabama
# 76                       NaN        NaN        NaN   butler county, Alabama
# 77                       NaN        NaN        NaN   butler county, Alabama
# 78                       NaN        NaN        NaN   butler county, Alabama
# 79                       NaN        NaN        NaN   butler county, Alabama
# 80                       NaN        NaN        NaN   butler county, Alabama
# 81                       NaN        NaN        NaN   butler county, Alabama
# 82                       NaN        NaN        NaN   butler county, Alabama
# 83                       NaN        NaN        NaN   butler county, Alabama
# 84                       NaN        NaN        NaN   butler county, Alabama
# 85                       NaN        NaN        NaN   butler county, Alabama
# 86              -999999999.0   112903.0    87743.0  calhoun county, Alabama
# 87              -999999999.0   113103.0    88608.0  calhoun county, Alabama
# 88              -999999999.0   113419.0    88077.0  calhoun county, Alabama
# 89              -999999999.0   114081.0    88332.0  calhoun county, Alabama
# 90              -999999999.0   118510.0    89517.0  calhoun county, Alabama
# 91              -999999999.0   117797.0    90496.0  calhoun county, Alabama
# 92              -999999999.0   117296.0    90042.0  calhoun county, Alabama
# 93              -999999999.0   116736.0    89557.0  calhoun county, Alabama
# 94              -999999999.0   115916.0    90494.0  calhoun county, Alabama
# 95              -999999999.0   115620.0    89330.0  calhoun county, Alabama
# 96              -999999999.0   114611.0    86350.0  calhoun county, Alabama
# 97              -999999999.0   114728.0    86907.0  calhoun county, Alabama
# 98              -999999999.0   114277.0    87105.0  calhoun county, Alabama
# 99              -999999999.0   113605.0    84545.0  calhoun county, Alabama

# %%
#Fill in missing values with nan, interpolate & backfill data by county
for col in list(df_.columns):
    if (df_[col].dtype!='object'):
        df_.loc[df_[col]<0,col]=np.nan
    df_[col]=df_.groupby('county_state')[col].apply(lambda group: group.interpolate())
    df_[col]=df_.groupby('county_state')[col].fillna(method='bfill')

#Drop any rows missing total population data
df_.dropna(subset=['total_pop'],inplace=True)

#Recast year as an integer
df.year=df.year.astype(int)

#Ensure that the diabetes values are marked as NaN for 2018 & 2019 (these are to be estimated later and are not in the 
#CDC data, but may have been interpolated by steps above)
df_.loc[df_.year==2018,'diabetes_%']=np.nan
df_.loc[df_.year==2019,'diabetes_%']=np.nan
df_.loc[df_.year==2018,'diabetes_%_upper']=np.nan
df_.loc[df_.year==2019,'diabetes_%_upper']=np.nan
df_.loc[df_.year==2018,'diabetes_%_lower']=np.nan
df_.loc[df_.year==2019,'diabetes_%_lower']=np.nan

#Remove all Puerto Rico data because there is no education data for any counties or years
df_=df_[~(df_.state=='Puerto Rico')]

#Fill missing Pacific Island pop with 0
df_.pacific_island_pop.fillna(value=0,inplace=True)

#Inspect data for missing values
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11296 entries, 12 to 40269
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               11296 non-null  object
#  1   county              11296 non-null  object
#  2   county_fips         11296 non-null  float64
#  3   state_fips          11296 non-null  float64
#  4   year                11296 non-null  float64
#  5   20_24_years         11296 non-null  float64
#  6   25_34_years         11296 non-null  float64
#  7   35_44_years         11296 non-null  float64
#  8   45_54_years         11296 non-null  float64
#  9   55_59_years         11296 non-null  float64
#  10  60_64_years         11296 non-null  float64
#  11  65_74_years         11296 non-null  float64
#  12  75_84_years         11296 non-null  float64
#  13  85_plus_years       11296 non-null  float64
#  14  amer_indian_pop     11296 non-null  float64
#  15  asian_pop           11296 non-null  float64
#  16  black_pop           11296 non-null  float64
#  17  diabetes_%          9684 non-null   float64
#  18  diabetes_%_lower    9684 non-null   float64
#  19  diabetes_%_upper    9684 non-null   float64
#  20  education_bach      11296 non-null  float64
#  21  education_hs        11296 non-null  float64
#  22  female              11296 non-null  float64
#  23  hispanic_pop        11296 non-null  float64
#  24  male                11296 non-null  float64
#  25  median_income       11296 non-null  float64
#  26  other_pop           11296 non-null  float64
#  27  pacific_island_pop  11296 non-null  float64
#  28  total_pop           11296 non-null  float64
#  29  white_pop           11296 non-null  float64
#  30  county_state        11296 non-null  object
# dtypes: float64(28), object(3)
# memory usage: 2.8+ MB

# %% [markdown]
# ## 4. Saving Data <a class="anchor" id="4.SavingData"></a>

# %%
#Write all county population & diabetes data to a csv file
df_pop_diabetes.to_csv('data/interim/population_diabetes_allcounties_2004_2017.csv')

#Write demographic & diabetes data for populous counties to a csv file
df_.to_csv('data/interim/diabetes_ACS_populous_counties_2004to2019.csv')
